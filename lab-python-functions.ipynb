# %% [markdown]
# # Lab | Functions

# %% [markdown]
# ## Exercise: Managing Customer Orders with Functions
#
# In the previous exercise, you improved the code for managing customer orders by using loops and flow control. Now, let's take it a step further and refactor the code by introducing functions.
#
# Follow the steps below to complete the exercise:
#
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.
#
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names (por ejemplo me va a quitar 5 unidades) using a loop. The function should return the `customer_orders` set.
#
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.
#
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.
#
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.
#
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.
#
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.
#
# Hints for functions:
#
# - Consider the input parameters required for each function and their return values.
# - Utilize function parameters and return values to transfer data between functions.
# - Test your functions individually to ensure they work correctly.

# %% [markdown]
# ---

# %% [markdown]
# 1  Define a function named `initialize_inventory`

# %% [markdown]
# 1. Define a function named `initialize_inventory` that takes `products` as a parameter. Inside the function, implement the code for initializing the inventory dictionary using a loop and user input.

# %%
   
def initialize_inventory(products):
    inventory = {}
    for product in products:
        quantity = int(input(f"Introduce la cantidad disponible de {product}: "))
        inventory[product] = quantity
    return inventory

# %% [markdown]
# 2. Define a function named `get_customer_orders` that takes no parameters. Inside the function, implement the code for prompting the user to enter the product names (por ejemplo me va a quitar 5 unidades) using a loop. The function should return the `customer_orders` set.

# %%
def get_customer_orders():
    customer_orders = {}
    sigue_pedido = input("¿Vas a pedir algo yes/no: ").lower()


    while sigue_pedido == "yes":
        producto = input("Dime qué quieres pedir: ")
        quantity = int(input(f"Dime que cantidad necesitas de {producto}: "))
        customer_orders[producto] = quantity
 

        sigue_pedido = input("¿Vas a pedir mas yes/no: ").lower()

    return customer_orders

# %% [markdown]
# 3. Define a function named `update_inventory` that takes `customer_orders` and `inventory` as parameters. Inside the function, implement the code for updating the inventory dictionary based on the customer orders.

# %%
def update_inventory(customer_orders ,inventory):
    for producto in customer_orders:
        if producto in inventory:
            quantity = int(input(f"Cuantos quieres pedir de {producto}"))
            inventory[producto] -= quantity
    return inventory

# %% [markdown]
# 4. Define a function named `calculate_order_statistics` that takes `customer_orders` and `products` as parameters. Inside the function, implement the code for calculating the order statistics (total products ordered, and percentage of unique products ordered). The function should return these values.

# %%
def calculate_order_statistics(customer_orders,products):
    
    percentage_of_unique_products_ordered = round((customer_orders /products)*100,2)
    return customer_orders, percentage_of_unique_products_ordered

# %% [markdown]
# 5. Define a function named `print_order_statistics` that takes `order_statistics` as a parameter. Inside the function, implement the code for printing the order statistics.

# %%
def print_order_statistics(order_statistics):
    print(f"total_products_ordered : {order_statistics[0]}")
    print(f"porcentage_of_unique_products_ordered: {order_statistics[1]}")

# %% [markdown]
# 6. Define a function named `print_updated_inventory` that takes `inventory` as a parameter. Inside the function, implement the code for printing the updated inventory.

# %%
def print_updated_inventory(inventory):
    for product, quantity in inventory.items():
        print(f"{product}: {quantity}")

    return

# %% [markdown]
# 7. Call the functions in the appropriate sequence to execute the program and manage customer orders.

# %%
lista_productos = ['manzanas', 'peras','melones', 'sandias']

# %%
inventory = initialize_inventory(lista_productos)

# %%
customer_orders = get_customer_orders()

# %%
inventory = update_inventory(customer_orders,inventory)

# %%
order_statistics = calculate_order_statistics (customer_orders,inventory)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 order_statistics = calculate_order_statistics (customer_orders,inventory)
#
# Cell In[4], line 3, in calculate_order_statistics(customer_orders, products)
#       1 def calculate_order_statistics(customer_orders,products):
# ----> 3     percentage_of_unique_products_ordered = round((customer_orders /products)*100,2)
#       4     return customer_orders, percentage_of_unique_products_ordered
#
# TypeError: unsupported operand type(s) for /: 'set' and 'dict'

# %%
order_statistics_imprimir = print_order_statistics(order_statistics)
# Out:
# total_products_ordered : 0
# porcentage_of_unique_products_ordered: 0.0

# %%
imprimir_inventario = print_updated_inventory(inventory)
# Out:
# manzanas: 40
# peras: 50
# melones: 60
# sandias: 70
